# %% [markdown]
# ******************
# ### Exploratory Data Analysis Utilizing Boston Housing Dataset

# %% [markdown]
#  ******************
#  **Note**: This sort of EDA is only for Python skill crafting and enhancing recently grasped data visualization skillset.
#
#  **Project Objectives**
#  * Study different features that affect house pricing.
#  * Identify and study features significantly affect pricing process.
#  * Apply regression to prdict the prices.

# %% [markdown]
# ******************
# **Importing Libraries**

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# ******************
# **Loading Data**
#
# **Data Source is Sklearn Lib.**

# %%
from sklearn.datasets import load_boston

# %% [markdown]
# ******************
# **Data Understanding**

# %%
boston = load_boston()
# Data stored as a Dictionary, key and value. 
boston
# Out:
# {'data': array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#          4.9800e+00],
#         [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#          9.1400e+00],
#         [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#          4.0300e+00],
#         ...,
#         [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#          5.6400e+00],
#         [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#          6.4800e+00],
#         [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#          7.8800e+00]]),
#  'target': array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#         18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#         15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#         13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
# ...

# %%
boston.keys()
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename'])

# %%
# Covert Data into a DataFrame
df = pd.DataFrame(boston.data,columns=boston.feature_names)
# adding Target Feature to the Dataset 
df["Target Price"] = boston.target
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  Target Price
# 0       15.3  396.90   4.98          24.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CRIM          506 non-null    float64
#  1   ZN            506 non-null    float64
#  2   INDUS         506 non-null    float64
#  3   CHAS          506 non-null    float64
#  4   NOX           506 non-null    float64
#  5   RM            506 non-null    float64
#  6   AGE           506 non-null    float64
#  7   DIS           506 non-null    float64
#  8   RAD           506 non-null    float64
#  9   TAX           506 non-null    float64
#  10  PTRATIO       506 non-null    float64
#  11  B             506 non-null    float64
#  12  LSTAT         506 non-null    float64
#  13  Target Price  506 non-null    float64
# dtypes: float64(14)
# memory usage: 55.5 KB

# %% [markdown]
# ******************
# **Main Statistics**

# %%
df.describe().T
# Out:
#          count        mean         std        min         25%        50%  \
# CRIM     506.0    3.613524    8.601545    0.00632    0.082045    0.25651
# ZN       506.0   11.363636   23.322453    0.00000    0.000000    0.00000
# INDUS    506.0   11.136779    6.860353    0.46000    5.190000    9.69000
# CHAS     506.0    0.069170    0.253994    0.00000    0.000000    0.00000
# NOX      506.0    0.554695    0.115878    0.38500    0.449000    0.53800
# RM       506.0    6.284634    0.702617    3.56100    5.885500    6.20850
# AGE      506.0   68.574901   28.148861    2.90000   45.025000   77.50000
# DIS      506.0    3.795043    2.105710    1.12960    2.100175    3.20745
# RAD      506.0    9.549407    8.707259    1.00000    4.000000    5.00000
# TAX      506.0  408.237154  168.537116  187.00000  279.000000  330.00000
# PTRATIO  506.0   18.455534    2.164946   12.60000   17.400000   19.05000
# B        506.0  356.674032   91.294864    0.32000  375.377500  391.44000
# ...

# %%
df.size
# Out:
# 7084

# %%
df.shape
# Out:
# (506, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    float64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  Target   506 non-null    float64
# dtypes: float64(14)
# memory usage: 55.5 KB

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  Target
# 0     15.3  396.90   4.98    24.0
# 1     17.8  396.90   9.14    21.6
# 2     17.8  392.83   4.03    34.7
# 3     18.7  394.63   2.94    33.4
# 4     18.7  396.90   5.33    36.2

# %% [markdown]
# ******************
# **Observing the Mean of the Features**

# %%
df.describe().iloc[2].plot.bar()
# OR 
df.describe().loc["mean"].plot.bar()
plt.show()
# Out:
# <AxesSubplot:>

# %%
des = pd.DataFrame(df.describe())
des.drop(index="count",axis=1,inplace=True)
des.head(1)
# Out:
#           CRIM         ZN      INDUS     CHAS       NOX        RM        AGE  \
# mean  3.613524  11.363636  11.136779  0.06917  0.554695  6.284634  68.574901
#
#            DIS       RAD         TAX    PTRATIO           B      LSTAT  \
# mean  3.795043  9.549407  408.237154  18.455534  356.674032  12.653063
#
#       Target Price
# mean     22.532806

# %%
df.isnull().sum()
# Out:
# CRIM            0
# ZN              0
# INDUS           0
# CHAS            0
# NOX             0
# RM              0
# AGE             0
# DIS             0
# RAD             0
# TAX             0
# PTRATIO         0
# B               0
# LSTAT           0
# Target Price    0
# dtype: int64

# %% [markdown]
# ###### correlation between Features & Target using heatmap.

# %%
df.corr()
# Out:
#                   CRIM        ZN     INDUS      CHAS       NOX        RM  \
# CRIM          1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247
# ZN           -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991
# INDUS         0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676
# CHAS         -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251
# NOX           0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188
# RM           -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000
# AGE           0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265
# DIS          -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246
# RAD           0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847
# TAX           0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048
# PTRATIO       0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501
# B            -0.385064  0.175520 -0.356977  0.048788 -0.380051  0.128069
# ...

# %%
plt.figure(figsize=(18,8))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
df.hist(figsize=(18,18));

# %% [markdown]
# ###### Detecting Outliers with Boxplot.

# %%
df.plot(kind = 'box',subplots=True, layout= (4,4),fontsize=8,figsize = (18,18));

# %%
sns.distplot(df['Target'])
# Out:
# C:\Users\mahmo\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Target', ylabel='Density'>

# %%
sns.pairplot(df[['ZN','INDUS','NOX','AGE','RM']],size=3)
plt.show()
# Out:
# C:\Users\mahmo\anaconda3\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# **Objective 1**
#
# - Study different features that affect house pricing.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CRIM          506 non-null    float64
#  1   ZN            506 non-null    float64
#  2   INDUS         506 non-null    float64
#  3   CHAS          506 non-null    float64
#  4   NOX           506 non-null    float64
#  5   RM            506 non-null    float64
#  6   AGE           506 non-null    float64
#  7   DIS           506 non-null    float64
#  8   RAD           506 non-null    float64
#  9   TAX           506 non-null    float64
#  10  PTRATIO       506 non-null    float64
#  11  B             506 non-null    float64
#  12  LSTAT         506 non-null    float64
#  13  Target Price  506 non-null    float64
# dtypes: float64(14)
# memory usage: 55.5 KB
